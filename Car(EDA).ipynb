# %% [markdown]
# # Exploratory Data Analysis of Automobile data

# %%
import pandas as pd
import numpy as np

# %%
auto_df= pd.read_csv(r'C:\Users\MOTIRAM SINGH\Downloads\automobileEDA.csv')

# %%
auto_df.shape
# Out:
# (201, 29)

# %%
pd.set_option('display.max_rows',300)

# %%
pd.set_option('display.max_columns',30)

# %%
auto_df.head(10)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
# 5          2                122         audi        std          two
# 6          1                158         audi        std         four
# 7          1                122         audi        std         four
# 8          1                158         audi      turbo         four
# 9          2                192          bmw        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length     width  \
# 0  convertible          rwd           front        88.6  0.811148  0.890278
# ...

# %%
auto_df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %%
def uni(df):
    for column in df.columns:
        uniq=df[column].unique()
        if len(uniq)<10:
            print(column,'   ',uniq,'   ',len(uniq))

# %%
uni(auto_df)
# Out:
# symboling     [ 3  1  2  0 -1 -2]     6
# aspiration     ['std' 'turbo']     2
# num-of-doors     ['two' 'four']     2
# body-style     ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']     5
# drive-wheels     ['rwd' 'fwd' '4wd']     3
# engine-location     ['front' 'rear']     2
# engine-type     ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf']     6
# num-of-cylinders     ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']     7
# fuel-system     ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']     8
# horsepower-binned     ['Medium' 'Low' 'High' nan]     4
# diesel     [0 1]     2
# gas     [1 0]     2

# %%
auto_df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
corr_matrix=auto_df.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig,ax=plt.subplots(figsize=(10,8))
heatmap=ax.imshow(corr_matrix,vmin=-1,vmax=+1)
ax.set_xticks(range(len(corr_matrix.columns)))
ax.set_yticks(range(len(corr_matrix.columns)))
ax.set_xticklabels(corr_matrix.columns,rotation=90)
ax.set_yticklabels(corr_matrix.columns)
bar=plt.colorbar(heatmap)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def le(df,column):
    le=LabelEncoder()
    df[column]=le.fit_transform(df[column])

# %%
le(auto_df,'num-of-doors')

# %%
auto_df.head()
# Out:
#    symboling  normalized-losses         make aspiration  num-of-doors  \
# 0          3                122  alfa-romero        std             1
# 1          3                122  alfa-romero        std             1
# 2          1                122  alfa-romero        std             1
# 3          2                164         audi        std             0
# 4          2                164         audi        std             0
#
#     body-style drive-wheels engine-location  wheel-base    length     width  \
# 0  convertible          rwd           front        88.6  0.811148  0.890278
# 1  convertible          rwd           front        88.6  0.811148  0.890278
# 2    hatchback          rwd           front        94.5  0.822681  0.909722
# 3        sedan          fwd           front        99.8  0.848630  0.919444
# 4        sedan          4wd           front        99.4  0.848630  0.922222
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# ...

# %%
auto_df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    int32
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %%
le(auto_df,'aspiration')
le(auto_df,'drive-wheels')
le(auto_df,'body-style')
le(auto_df,'engine-location')
le(auto_df,'engine-type')
le(auto_df,'num-of-cylinders')

# %%
le(auto_df,'fuel-system')
le(auto_df,'horsepower-binned')

# %%
auto_df.head()
# Out:
#    symboling  normalized-losses         make  aspiration  num-of-doors  \
# 0          3                122  alfa-romero           0             1
# 1          3                122  alfa-romero           0             1
# 2          1                122  alfa-romero           0             1
# 3          2                164         audi           0             0
# 4          2                164         audi           0             0
#
#    body-style  drive-wheels  engine-location  wheel-base    length     width  \
# 0           0             2                0        88.6  0.811148  0.890278
# 1           0             2                0        88.6  0.811148  0.890278
# 2           2             2                0        94.5  0.822681  0.909722
# 3           3             1                0        99.8  0.848630  0.919444
# 4           3             0                0        99.4  0.848630  0.922222
#
#    height  curb-weight  engine-type  num-of-cylinders  engine-size  \
# ...

# %%
df=auto_df.drop(['make'],axis=1)

# %%
df.head()
# Out:
#    symboling  normalized-losses  aspiration  num-of-doors  body-style  \
# 0          3                122           0             1           0
# 1          3                122           0             1           0
# 2          1                122           0             1           2
# 3          2                164           0             0           3
# 4          2                164           0             0           3
#
#    drive-wheels  engine-location  wheel-base    length     width  height  \
# 0             2                0        88.6  0.811148  0.890278    48.8
# 1             2                0        88.6  0.811148  0.890278    48.8
# 2             2                0        94.5  0.822681  0.909722    52.4
# 3             1                0        99.8  0.848630  0.919444    54.3
# 4             0                0        99.4  0.848630  0.922222    54.3
#
#    curb-weight  engine-type  num-of-cylinders  engine-size  fuel-system  bore  \
# ...

# %%
def plot_correlation_heatmap(corr_matrix):
    fig, ax = plt.subplots(figsize=(10, 8))
    heatmap = ax.imshow(corr_matrix, vmin=-1, vmax=1)
    ax.set_xticks(range(len(corr_matrix.columns)))
    ax.set_yticks(range(len(corr_matrix.columns)))
    ax.set_xticklabels(corr_matrix.columns, rotation=90)
    ax.set_yticklabels(corr_matrix.columns)
    bar = plt.colorbar(heatmap)
    plt.show()

# %%
corr_df=df.corr()

# %%
plot_correlation_heatmap(corr_df)

# %%
corr_df
# Out:
#                    symboling  normalized-losses  aspiration  num-of-doors  \
# symboling           1.000000       4.662638e-01   -0.054615      0.672344
# normalized-losses   0.466264       1.000000e+00   -0.006911      0.361368
# aspiration         -0.054615      -6.910980e-03    1.000000     -0.063017
# num-of-doors        0.672344       3.613676e-01   -0.063017      1.000000
# body-style         -0.600333      -2.517751e-01    0.072079     -0.688542
# drive-wheels       -0.053056       3.172142e-01    0.094469      0.115920
# engine-location     0.212339       1.355890e-17   -0.057496      0.142340
# wheel-base         -0.535987      -5.666124e-02    0.256889     -0.445245
# length             -0.365404       1.942356e-02    0.230085     -0.395122
# width              -0.242423       8.680206e-02    0.305732     -0.227655
# height             -0.550160      -3.737370e-01    0.090336     -0.538383
# curb-weight        -0.233118       9.940425e-02    0.321955     -0.208517
# ...

# %%
df[['price','num-of-cylinders',]].corr()
# Out:
#                      price  num-of-cylinders
# price             1.000000          0.005509
# num-of-cylinders  0.005509          1.000000

# %%
df[['price','num-of-cylinders','body-style']].corr()
# Out:
#                      price  num-of-cylinders  body-style
# price             1.000000          0.005509   -0.072933
# num-of-cylinders  0.005509          1.000000   -0.063741
# body-style       -0.072933         -0.063741    1.000000

# %%
sns.regplot(x='engine-size',y='price',data=df)#strong relation
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
sns.regplot(x='num-of-doors',y='price',data=df)#weak relation
# Out:
# <AxesSubplot:xlabel='num-of-doors', ylabel='price'>

# %%
sns.regplot(x='highway-mpg',y='price',data=df)#strong and negetive relation
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %%
uni(df)
# Out:
# symboling     [ 3  1  2  0 -1 -2]     6
# aspiration     [0 1]     2
# num-of-doors     [1 0]     2
# body-style     [0 2 3 4 1]     5
# drive-wheels     [2 1 0]     3
# engine-location     [0 1]     2
# engine-type     [0 4 2 1 5 3]     6
# num-of-cylinders     [2 3 1 4 5 6 0]     7
# fuel-system     [5 1 4 0 7 2 3 6]     8
# horsepower-binned     [2 1 0 3]     4
# diesel     [0 1]     2
# gas     [1 0]     2

# %%
sns.boxplot(x='body-style',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x='drive-wheels',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='price'>

# %%
auto_df1['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
sns.boxplot(x='body-style',y='price',data=auto_df1)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
group=auto_df1[['body-style','price']]

# %%
group.head(15)
# Out:
#      body-style    price
# 0   convertible  13495.0
# 1   convertible  16500.0
# 2     hatchback  16500.0
# 3         sedan  13950.0
# 4         sedan  17450.0
# 5         sedan  15250.0
# 6         sedan  17710.0
# 7         wagon  18920.0
# 8         sedan  23875.0
# 9         sedan  16430.0
# 10        sedan  16925.0
# 11        sedan  20970.0
# 12        sedan  21105.0
# 13        sedan  24565.0
# 14        sedan  30760.0

# %%
group_1=group.groupby('body-style',as_index=False).mean()
group_1
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
sns.barplot(y='price',x='body-style',data=group_1)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
from scipy import stats

# %%
pear,p=stats.pearsonr(df['price'],df['horsepower'])

# %%
pear
# Out:
# 0.8095745670036555

# %%
p
# Out:
# 6.369057428261186e-48

# %%
auto_df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
auto_df1.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
ano1 = auto_df1[['num-of-doors', 'price']]
ano1.groupby('num-of-doors',as_index=False).mean()
# Out:
#   num-of-doors         price
# 0         four  13498.034783
# 1          two  12818.127907

# %%
group.head()
# Out:
#     body-style    price
# 0  convertible  13495.0
# 1  convertible  16500.0
# 2    hatchback  16500.0
# 3        sedan  13950.0
# 4        sedan  17450.0

# %%
group_1
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
auto_df.nunique()
# Out:
# symboling              6
# normalized-losses     51
# make                  22
# aspiration             2
# num-of-doors           2
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            52
# length                73
# width                 43
# height                49
# curb-weight          169
# engine-type            6
# num-of-cylinders       7
# engine-size           43
# fuel-system            8
# bore                  39
# stroke                36
# compression-ratio     32
# horsepower            59
# peak-rpm              23
# city-mpg              29
# highway-mpg           30
# price                186
# city-L/100km          29
# horsepower-binned      4
# diesel                 2
# gas                    2
# dtype: int64
